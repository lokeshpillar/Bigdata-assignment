# %%
# Install the Cassandra python driver
# !pip install cassandra-driver
# Out:
# Requirement already satisfied: cassandra-driver in ./anaconda3/lib/python3.11/site-packages (3.29.2)
# Requirement already satisfied: geomet<0.3,>=0.1 in ./anaconda3/lib/python3.11/site-packages (from cassandra-driver) (0.2.1.post1)
# Requirement already satisfied: click in ./anaconda3/lib/python3.11/site-packages (from geomet<0.3,>=0.1->cassandra-driver) (8.1.7)
# Requirement already satisfied: six in ./anaconda3/lib/python3.11/site-packages (from geomet<0.3,>=0.1->cassandra-driver) (1.16.0)

# %%
# Import the necessary libraries
from cassandra.cluster import Cluster
from cassandra.auth import PlainTextAuthProvider
import json

# %%
# This secure connect bundle is autogenerated when you download your SCB,
# if yours is different update the file name below
cloud_config= {
  'secure_connect_bundle': 'secure-connect-rowan.zip'
}

# This token JSON file is autogenerated when you download your token,
# if yours is different update the file name below
with open("rowan-token.json") as f:
    secrets = json.load(f)

    CLIENT_ID = "YGdMEKJlBMBPflgZNNHDeSCP"
    CLIENT_SECRET = "oKj+DFBI0Crp-S7dkP5QXELf8MteD8BNZ4bfXmTEwLi,ONIb2znQXArKMAtWnvJ7xw.T3Jg8kExnfJh54rdJSXmqStkvDBCqxSpM5.bgiSa_MfZT7ABuZ9P22jwY08N6"


auth_provider = PlainTextAuthProvider(CLIENT_ID, CLIENT_SECRET)
cluster = Cluster(cloud=cloud_config, auth_provider=auth_provider)
session = cluster.connect()

if session:
  print('Connected!')
else:
  print("An error occurred.")
# Out:
# Connected!

# %%
session.set_keyspace('bigdata')  # Replace 'your_keyspace' with the correct name
print(f"Connected to keyspace: {session.keyspace}")
# Out:
# Connected to keyspace: bigdata

# %%
rows = session.execute("SELECT table_name FROM system_schema.tables WHERE keyspace_name = 'bigdata'")
print("Existing tables:")
for row in rows:
    print(row.table_name)
# Out:
# Existing tables:

# %%
# Get a list of all tables in the keyspace
rows = session.execute("SELECT table_name FROM system_schema.tables WHERE keyspace_name = 'bigdata'")

# Drop each table
for row in rows:
    table_name = row.table_name
    try:
        session.execute(f"DROP TABLE IF EXISTS {table_name};")
        print(f"Table {table_name} dropped successfully.")
    except Exception as e:
        print(f"Error dropping table {table_name}: {e}")

# %%
session.execute("""
CREATE TABLE IF NOT EXISTS sales_bronze (
    region TEXT,
    country TEXT,
    item_type TEXT,
    sales_channel TEXT,
    order_priority TEXT,
    order_date TEXT,
    order_id UUID PRIMARY KEY,
    ship_date TEXT,
    units_sold INT,
    unit_price FLOAT,
    unit_cost FLOAT,
    total_revenue FLOAT,
    total_cost FLOAT,
    total_profit FLOAT
);
""")
print("Table sales_bronze created successfully.")
# Out:
# Table sales_bronze created successfully.

# %%
url = '/Users/lokeshreddy/Downloads/sales_100.csv'  # Replace with the actual file name after upload

# %%
import pandas as pd
import uuid

# Load data from CSV into a DataFrame
file_path = '/Users/lokeshreddy/Downloads/sales_100.csv'
df = pd.read_csv(file_path)

# Iterate over the DataFrame rows
for _, row in df.iterrows():
    session.execute("""
        INSERT INTO sales_bronze (
            region, country, item_type, sales_channel, order_priority,
            order_date, order_id, ship_date, units_sold, unit_price,
            unit_cost, total_revenue, total_cost, total_profit
        ) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
    """, (
        row['Region'], 
        row['Country'], 
        row['Item Type'], 
        row['Sales Channel'],
        row['Order Priority'], 
        row['Order Date'], 
        uuid.uuid4(),  # Pass the UUID object directly
        row['Ship Date'], 
        row['UnitsSold'],  # Ensure this matches your actual column name
        row['UnitPrice'],
        row['UnitCost'], 
        row['TotalRevenue'], 
        row['TotalCost'], 
        row['TotalProfit']
    ))

print("Data inserted into sales_bronze.")
# Out:
# Data inserted into sales_bronze.

# %%
rows = session.execute("SELECT * FROM sales_bronze LIMIT 10;")
for row in rows:
    print(row)
# Out:
# Row(order_id=UUID('2d873d8e-6d62-410e-8fac-27da678744b3'), country='Albania', item_type='Baby Food', order_date='7/19/2012', order_priority='H', region='Europe', sales_channel='Offline', ship_date='8/13/2012', total_cost=1257823.75, total_profit=756335.375, total_revenue=2014159.25, unit_cost=159.4199981689453, unit_price=255.27999877929688, units_sold=7890)
# Row(order_id=UUID('4611c8d7-e613-485f-9c5d-c65a1918d4ee'), country='Saint Lucia', item_type='Fruits', order_date='12/12/2015', order_priority='L', region='Central America and the Caribbean', sales_channel='Offline', ship_date='1/12/2016', total_cost=24780.51953125, total_profit=8630.2099609375, total_revenue=33410.73046875, unit_cost=6.920000076293945, unit_price=9.329999923706055, units_sold=3581)
# Row(order_id=UUID('4704ef3a-8038-4606-979c-8fa11de77f94'), country='Haiti', item_type='Office Supplies', order_date='12/31/2010', order_priority='C', region='Central America and the Caribbean', sales_channel='Online', ship_date='1/31/2011', total_cost=1077217.875, total_profit=259065.0, total_revenue=1336282.875, unit_cost=524.9600219726562, unit_price=651.2100219726562, units_sold=2052)
# Row(order_id=UUID('f6e1b36e-6b2d-4680-b00b-c8ca27f9d547'), country='India', item_type='Snacks', order_date='10/10/2012', order_priority='L', region='Asia', sales_channel='Online', ship_date='11/20/2012', total_cost=521206.5625, total_profit=294943.875, total_revenue=816150.4375, unit_cost=97.44000244140625, unit_price=152.5800018310547, units_sold=5349)
# Row(order_id=UUID('f4f82d56-ccea-4ccc-874f-ba8f0757d1d3'), country='Thailand', item_type='Meat', order_date='2/4/2015', order_priority='C', region='Asia', sales_channel='Online', ship_date='2/19/2015', total_cost=1605000.75, total_profit=251737.203125, total_revenue=1856737.875, unit_cost=364.69000244140625, unit_price=421.8900146484375, units_sold=4401)
# Row(order_id=UUID('29906647-8592-471e-baf5-3b0a551d29ae'), country='Malaysia', item_type='Beverages', order_date='11/13/2014', order_priority='M', region='Asia', sales_channel='Online', ship_date='12/28/2014', total_cost=291005.65625, total_profit=143351.640625, total_revenue=434357.3125, unit_cost=31.790000915527344, unit_price=47.45000076293945, units_sold=9154)
# Row(order_id=UUID('ce22dac7-3fdb-4a8b-b8b9-c0b497281570'), country='Tonga', item_type='Baby Food', order_date='5/11/2016', order_priority='L', region='Australia and Oceania', sales_channel='Online', ship_date='5/31/2016', total_cost=881752.0, total_profit=530201.6875, total_revenue=1411953.625, unit_cost=159.4199981689453, unit_price=255.27999877929688, units_sold=5531)
# Row(order_id=UUID('b29c3d4a-6bde-4337-90dd-bb57b9d94715'), country='Montenegro', item_type='Clothes', order_date='9/4/2016', order_priority='M', region='Europe', sales_channel='Offline', ship_date='9/8/2016', total_cost=75873.28125, total_profit=155472.484375, total_revenue=231345.765625, unit_cost=35.84000015258789, unit_price=109.27999877929688, units_sold=2117)
# Row(order_id=UUID('09ec5457-1e92-44c0-ab91-15391db84ad5'), country='Nicaragua', item_type='Household', order_date='10/28/2015', order_priority='C', region='Central America and the Caribbean', sales_channel='Online', ship_date='12/7/2015', total_cost=3915289.25, total_profit=1291202.375, total_revenue=5206491.5, unit_cost=502.5400085449219, unit_price=668.27001953125, units_sold=7791)
# Row(order_id=UUID('9f262305-184c-4bfa-928a-0a14b17090b8'), country='Serbia', item_type='Clothes', order_date='7/6/2016', order_priority='L', region='Europe', sales_channel='Offline', ship_date='7/13/2016', total_cost=263352.3125, total_profit=539637.125, total_revenue=802989.4375, unit_cost=35.84000015258789, unit_price=109.27999877929688, units_sold=7348)

# %%
import pandas as pd

# Load the CSV file into a DataFrame
file_path = '/Users/lokeshreddy/Downloads/sales_100.csv'
df = pd.read_csv(file_path)
 # Replace with the correct path to your file

# Check for missing (null) values
null_values = df.isnull().sum()

# Print the columns with missing values
print(null_values)
# Out:
# Region            0
# Country           0
# Item Type         0
# Sales Channel     0
# Order Priority    0
# Order Date        0
# Order ID          0
# Ship Date         0
# UnitsSold         0
# UnitPrice         0
# UnitCost          0
# TotalRevenue      0
# TotalCost         0
# TotalProfit       0
# dtype: int64

# %%
session.execute("""
CREATE TABLE IF NOT EXISTS sales_silver (
    order_id UUID PRIMARY KEY,
    region TEXT,
    country TEXT,
    item_type TEXT,
    total_profit FLOAT
);
""")
print("Table sales_silver created successfully.")
# Out:
# Table sales_silver created successfully.

# %%
rows = session.execute("SELECT order_id, region, country, item_type, total_profit FROM sales_bronze;")
for row in rows:
    session.execute("""
        INSERT INTO sales_silver (order_id, region, country, item_type, total_profit)
        VALUES (%s, %s, %s, %s, %s)
    """, (row.order_id, row.region, row.country, row.item_type, row.total_profit))

print("Data successfully inserted into sales_silver.")
# Out:
# Data successfully inserted into sales_silver.

# %%
session.execute("""
CREATE TABLE IF NOT EXISTS sales_silver (
    order_id UUID PRIMARY KEY,
    region TEXT,
    country TEXT,
    item_type TEXT,
    total_profit FLOAT
);
""")
print("Table sales_silver created successfully.")
# Out:
# Table sales_silver created successfully.

# %%
rows = session.execute("SELECT order_id, region, country, item_type, total_profit FROM sales_bronze;")
for row in rows:
    session.execute("""
        INSERT INTO sales_silver (order_id, region, country, item_type, total_profit)
        VALUES (%s, %s, %s, %s, %s)
    """, (row.order_id, row.region, row.country, row.item_type, row.total_profit))

print("Data successfully inserted into sales_silver.")
# Out:
# Data successfully inserted into sales_silver.

# %%
session.execute("""
CREATE TABLE IF NOT EXISTS sales_by_region (
    region TEXT PRIMARY KEY,
    total_profit FLOAT
);
""")
print("Table sales_by_region created successfully.")
# Out:
# Table sales_by_region created successfully.

# %%
import pandas as pd

# Step 1: Load data from sales_bronze
query = "SELECT region, total_profit FROM sales_bronze"
rows = session.execute(query)

# Convert the data into a Pandas DataFrame for easy aggregation
df = pd.DataFrame(rows)

# Step 2: Perform the aggregation in Python
aggregated_data = df.groupby('region', as_index=False).agg({'total_profit': 'sum'})

# Step 3: Insert aggregated data into the sales_by_region table
for index, row in aggregated_data.iterrows():
    session.execute("""
        INSERT INTO sales_by_region (region, total_profit)
        VALUES (%s, %s)
    """, (row['region'], row['total_profit']))

print("Data successfully inserted into sales_by_region.")
# Out:
# Data successfully inserted into sales_by_region.

# %%
session.execute("""
CREATE TABLE IF NOT EXISTS sales_by_region (
    region TEXT PRIMARY KEY,
    total_profit FLOAT
);
""")
print("Table sales_by_region created successfully.")
# Out:
# Table sales_by_region created successfully.

# %%
import pandas as pd

# Step 1: Load data from sales_bronze (assuming you have a 'sales_bronze' table)
query = "SELECT region, total_profit FROM sales_bronze"
rows = session.execute(query)

# Convert to Pandas DataFrame for easy aggregation
df = pd.DataFrame(rows)

# Step 2: Aggregate data by 'region'
aggregated_data = df.groupby('region', as_index=False).agg({'total_profit': 'sum'})

# Step 3: Insert the aggregated data into the sales_by_region table
for index, row in aggregated_data.iterrows():
    session.execute("""
        INSERT INTO sales_by_region (region, total_profit)
        VALUES (%s, %s)
    """, (row['region'], row['total_profit']))

print("Data successfully inserted into sales_by_region.")
# Out:
# Data successfully inserted into sales_by_region.

# %%
session.execute("""
CREATE TABLE IF NOT EXISTS sales_by_item_type (
    item_type TEXT PRIMARY KEY,
    total_units_sold INT
);
""")
print("Table sales_by_item_type created successfully.")
# Out:
# Table sales_by_item_type created successfully.

# %%
import pandas as pd

# Step 1: Load data from sales_bronze (assuming you have a 'sales_bronze' table)
query = "SELECT item_type, units_sold FROM sales_bronze"
rows = session.execute(query)

# Convert to Pandas DataFrame for easy aggregation
df = pd.DataFrame(rows)

# Step 2: Aggregate data by 'item_type'
aggregated_data = df.groupby('item_type', as_index=False).agg({'units_sold': 'sum'})

# Step 3: Insert the aggregated data into the sales_by_item_type table
for index, row in aggregated_data.iterrows():
    session.execute("""
        INSERT INTO sales_by_item_type (item_type, total_units_sold)
        VALUES (%s, %s)
    """, (row['item_type'], row['units_sold']))

print("Data successfully inserted into sales_by_item_type.")
# Out:
# Data successfully inserted into sales_by_item_type.

# %%
session.execute("""
CREATE TABLE IF NOT EXISTS monthly_sales_summary (
    order_date TEXT PRIMARY KEY,
    total_revenue FLOAT
);
""")
print("Table monthly_sales_summary created successfully.")
# Out:
# Table monthly_sales_summary created successfully.

# %%
import pandas as pd

# Step 1: Retrieve data from sales_bronze (assuming you have the 'sales_bronze' table)
query = "SELECT order_date, total_revenue FROM sales_bronze"
rows = session.execute(query)

# Convert to Pandas DataFrame for easy aggregation
df = pd.DataFrame(rows)

# Step 2: Aggregate data by 'order_date'
aggregated_data = df.groupby('order_date', as_index=False).agg({'total_revenue': 'sum'})

# Step 3: Insert the aggregated data into the monthly_sales_summary table
for index, row in aggregated_data.iterrows():
    session.execute("""
        INSERT INTO monthly_sales_summary (order_date, total_revenue)
        VALUES (%s, %s)
    """, (row['order_date'], row['total_revenue']))

print("Data successfully inserted into monthly_sales_summary.")
# Out:
# Data successfully inserted into monthly_sales_summary.

# %%
# Query Gold tables and print results
tables = ["sales_by_region", "sales_by_item_type", "monthly_sales_summary"]

for table in tables:
    print(f"Data from {table}:")
    rows = session.execute(f"SELECT * FROM {table};")
    for row in rows:
        print(row)
# Out:
# Data from sales_by_region:
# Row(region='Australia and Oceania', total_profit=3486940.0)
# Row(region='Europe', total_profit=11267281.0)
# Row(region='Middle East and North Africa', total_profit=6514262.0)
# Row(region='Central America and the Caribbean', total_profit=4252300.0)
# Row(region='Asia', total_profit=6749896.0)
# Row(region='Sub-Saharan Africa', total_profit=7651892.0)
# Row(region='North America', total_profit=1404621.5)
# Data from sales_by_item_type:
# Row(item_type='Household', total_units_sold=57640)
# Row(item_type='Office Supplies', total_units_sold=42814)
# Row(item_type='Vegetables', total_units_sold=7368)
# Row(item_type='Snacks', total_units_sold=14377)
# Row(item_type='Personal Care', total_units_sold=39045)
# Row(item_type='Meat', total_units_sold=50437)
# Row(item_type='Fruits', total_units_sold=65920)
# Row(item_type='Beverages', total_units_sold=45206)
# Row(item_type='Cereal', total_units_sold=45776)
# Row(item_type='Cosmetics', total_units_sold=65707)
# Row(item_type='Baby Food', total_units_sold=20372)
# Row(item_type='Clothes', total_units_sold=40148)
# Data from monthly_sales_summary:
# Row(order_date='7/1/2012', total_revenue=1071140.0)
# Row(order_date='9/5/2012', total_revenue=56530.46875)
# Row(order_date='2/4/2015', total_revenue=1856737.875)
# Row(order_date='1/27/2013', total_revenue=34856.87890625)
# Row(order_date='10/11/2012', total_revenue=274640.59375)
# Row(order_date='11/7/2011', total_revenue=12866.0703125)
# Row(order_date='5/17/2017', total_revenue=61415.359375)
# Row(order_date='1/19/2011', total_revenue=746767.0)
# Row(order_date='1/15/2016', total_revenue=5445064.0)
# Row(order_date='4/11/2010', total_revenue=1932962.875)
# Row(order_date='11/19/2011', total_revenue=4707294.0)
# Row(order_date='9/8/2015', total_revenue=2101183.25)
# Row(order_date='7/29/2014', total_revenue=3672173.25)
# Row(order_date='5/11/2016', total_revenue=1411953.625)
# Row(order_date='6/20/2014', total_revenue=1168581.75)
# Row(order_date='12/5/2016', total_revenue=3780403.5)
# Row(order_date='10/17/2016', total_revenue=339860.8125)
# Row(order_date='11/11/2015', total_revenue=301612.8125)
# Row(order_date='10/22/2012', total_revenue=760579.375)
# Row(order_date='11/13/2014', total_revenue=434357.3125)
# Row(order_date='11/1/2011', total_revenue=231050.703125)
# Row(order_date='2/21/2014', total_revenue=4006267.5)
# Row(order_date='3/23/2017', total_revenue=583484.1875)
# Row(order_date='10/20/2014', total_revenue=89558.671875)
# Row(order_date='11/2/2011', total_revenue=419198.09375)
# Row(order_date='12/7/2015', total_revenue=2570673.75)
# Row(order_date='3/16/2016', total_revenue=3012716.5)
# Row(order_date='9/28/2011', total_revenue=416332.21875)
# Row(order_date='2/10/2016', total_revenue=3771157.0)
# Row(order_date='5/23/2016', total_revenue=3396169.5)
# Row(order_date='8/19/2010', total_revenue=2884921.5)
# Row(order_date='3/1/2016', total_revenue=2149107.75)
# Row(order_date='6/14/2015', total_revenue=288752.09375)
# Row(order_date='11/30/2016', total_revenue=70036.203125)
# Row(order_date='1/18/2013', total_revenue=28327.650390625)
# Row(order_date='3/29/2011', total_revenue=1896974.75)
# Row(order_date='4/13/2015', total_revenue=1027580.1875)
# Row(order_date='5/9/2011', total_revenue=3263260.75)
# Row(order_date='11/29/2010', total_revenue=3470056.5)
# Row(order_date='7/7/2011', total_revenue=289426.40625)
# Row(order_date='6/23/2012', total_revenue=6253569.5)
# Row(order_date='10/9/2012', total_revenue=107533.8828125)
# Row(order_date='6/18/2010', total_revenue=44224.19921875)
# Row(order_date='3/8/2017', total_revenue=3699975.25)
# Row(order_date='10/28/2015', total_revenue=5206491.5)
# Row(order_date='4/4/2010', total_revenue=652532.3125)
# Row(order_date='9/4/2016', total_revenue=231345.765625)
# Row(order_date='6/12/2012', total_revenue=298982.4375)
# Row(order_date='11/15/2011', total_revenue=1456356.0)
# Row(order_date='7/6/2016', total_revenue=802989.4375)
# Row(order_date='2/6/2016', total_revenue=126109.390625)
# Row(order_date='2/19/2012', total_revenue=217368.453125)
# Row(order_date='4/30/2017', total_revenue=2196359.25)
# Row(order_date='9/30/2012', total_revenue=14508.150390625)
# Row(order_date='5/15/2015', total_revenue=151880.40625)
# Row(order_date='9/1/2011', total_revenue=6666661.5)
# Row(order_date='10/2/2011', total_revenue=4100669.25)
# Row(order_date='1/28/2013', total_revenue=1171204.125)
# Row(order_date='9/14/2013', total_revenue=503890.09375)
# Row(order_date='6/20/2011', total_revenue=993573.75)
# Row(order_date='2/18/2011', total_revenue=4227287.0)
# Row(order_date='11/17/2012', total_revenue=603225.625)
# Row(order_date='8/25/2011', total_revenue=69946.71875)
# Row(order_date='11/20/2011', total_revenue=81161.671875)
# Row(order_date='1/21/2016', total_revenue=348496.71875)
# Row(order_date='6/6/2015', total_revenue=337990.71875)
# Row(order_date='6/13/2011', total_revenue=979683.8125)
# Row(order_date='2/9/2014', total_revenue=74957.21875)
# Row(order_date='7/16/2014', total_revenue=5608790.0)
# Row(order_date='12/31/2010', total_revenue=1336282.875)
# Row(order_date='11/3/2013', total_revenue=53507.55078125)
# Row(order_date='3/28/2011', total_revenue=6266594.0)
# Row(order_date='10/26/2016', total_revenue=188518.84375)
# Row(order_date='9/8/2013', total_revenue=429730.1875)
# Row(order_date='10/10/2012', total_revenue=816150.4375)
# Row(order_date='3/22/2014', total_revenue=4003440.5)
# Row(order_date='6/19/2014', total_revenue=36860.23046875)
# Row(order_date='9/13/2012', total_revenue=117913.25)
# Row(order_date='7/19/2012', total_revenue=2014159.25)
# Row(order_date='12/12/2015', total_revenue=33410.73046875)
# Row(order_date='12/17/2010', total_revenue=2823440.75)
# Row(order_date='3/9/2011', total_revenue=167640.84375)
# Row(order_date='4/16/2015', total_revenue=1509220.875)
# Row(order_date='2/28/2015', total_revenue=2636753.25)
# Row(order_date='11/30/2015', total_revenue=643018.1875)
# Row(order_date='11/11/2016', total_revenue=738014.5)
# Row(order_date='5/1/2015', total_revenue=453813.59375)
# Row(order_date='7/27/2012', total_revenue=14862.6904296875)
# Row(order_date='5/29/2016', total_revenue=136140.640625)
# Row(order_date='11/19/2016', total_revenue=92245.7109375)
# Row(order_date='8/22/2015', total_revenue=1784241.75)
# Row(order_date='10/2/2010', total_revenue=628499.375)
# Row(order_date='10/7/2012', total_revenue=1297172.375)
# Row(order_date='8/9/2016', total_revenue=130261.7578125)
# Row(order_date='12/28/2013', total_revenue=4205821.5)
# Row(order_date='5/28/2013', total_revenue=868465.375)

# %%
import pandas as pd

# Load the data
file_path = '/Users/lokeshreddy/Downloads/sales_100.csv'
df = pd.read_csv(file_path)

# Convert the 'Order Date' and 'Ship Date' columns to datetime format
df['Order Date'] = pd.to_datetime(df['Order Date'], errors='coerce', dayfirst=True)
df['Ship Date'] = pd.to_datetime(df['Ship Date'], errors='coerce', dayfirst=True)

# Check the cleaned data
print(df[['Order Date', 'Ship Date']].head())
# Out:
#   Order Date  Ship Date
# 0 2012-07-27 2012-07-28
# 1 2013-09-14 2013-10-19
# 2 2015-05-15 2015-04-06
# 3 2017-05-17 2017-02-07
# 4 2016-10-26 2016-04-12
# /var/folders/f2/0xb9nfvn0g3cbp8m5pqy94nw0000gn/T/ipykernel_80966/1744277177.py:8: UserWarning: Parsing dates in MM/DD/YYYY format when dayfirst=True was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df['Order Date'] = pd.to_datetime(df['Order Date'], errors='coerce', dayfirst=True)
# /var/folders/f2/0xb9nfvn0g3cbp8m5pqy94nw0000gn/T/ipykernel_80966/1744277177.py:9: UserWarning: Parsing dates in MM/DD/YYYY format when dayfirst=True was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df['Ship Date'] = pd.to_datetime(df['Ship Date'], errors='coerce', dayfirst=True)

# %%
# Query for Bronze table
bronze_query = "SELECT * FROM sales_bronze;"
bronze_data = session.execute(bronze_query)

print("------ Bronze Table Data ------")
for row in bronze_data:
    print(row)

# Query for Silver table
silver_query = "SELECT * FROM sales_silver;"
silver_data = session.execute(silver_query)

print("\n------ Silver Table Data ------")
for row in silver_data:
    print(row)
# Out:
# ------ Bronze Table Data ------
# Row(order_id=UUID('2d873d8e-6d62-410e-8fac-27da678744b3'), country='Albania', item_type='Baby Food', order_date='7/19/2012', order_priority='H', region='Europe', sales_channel='Offline', ship_date='8/13/2012', total_cost=1257823.75, total_profit=756335.375, total_revenue=2014159.25, unit_cost=159.4199981689453, unit_price=255.27999877929688, units_sold=7890)
# Row(order_id=UUID('4611c8d7-e613-485f-9c5d-c65a1918d4ee'), country='Saint Lucia', item_type='Fruits', order_date='12/12/2015', order_priority='L', region='Central America and the Caribbean', sales_channel='Offline', ship_date='1/12/2016', total_cost=24780.51953125, total_profit=8630.2099609375, total_revenue=33410.73046875, unit_cost=6.920000076293945, unit_price=9.329999923706055, units_sold=3581)
# Row(order_id=UUID('4704ef3a-8038-4606-979c-8fa11de77f94'), country='Haiti', item_type='Office Supplies', order_date='12/31/2010', order_priority='C', region='Central America and the Caribbean', sales_channel='Online', ship_date='1/31/2011', total_cost=1077217.875, total_profit=259065.0, total_revenue=1336282.875, unit_cost=524.9600219726562, unit_price=651.2100219726562, units_sold=2052)
# Row(order_id=UUID('f6e1b36e-6b2d-4680-b00b-c8ca27f9d547'), country='India', item_type='Snacks', order_date='10/10/2012', order_priority='L', region='Asia', sales_channel='Online', ship_date='11/20/2012', total_cost=521206.5625, total_profit=294943.875, total_revenue=816150.4375, unit_cost=97.44000244140625, unit_price=152.5800018310547, units_sold=5349)
# Row(order_id=UUID('f4f82d56-ccea-4ccc-874f-ba8f0757d1d3'), country='Thailand', item_type='Meat', order_date='2/4/2015', order_priority='C', region='Asia', sales_channel='Online', ship_date='2/19/2015', total_cost=1605000.75, total_profit=251737.203125, total_revenue=1856737.875, unit_cost=364.69000244140625, unit_price=421.8900146484375, units_sold=4401)
# Row(order_id=UUID('29906647-8592-471e-baf5-3b0a551d29ae'), country='Malaysia', item_type='Beverages', order_date='11/13/2014', order_priority='M', region='Asia', sales_channel='Online', ship_date='12/28/2014', total_cost=291005.65625, total_profit=143351.640625, total_revenue=434357.3125, unit_cost=31.790000915527344, unit_price=47.45000076293945, units_sold=9154)
# Row(order_id=UUID('ce22dac7-3fdb-4a8b-b8b9-c0b497281570'), country='Tonga', item_type='Baby Food', order_date='5/11/2016', order_priority='L', region='Australia and Oceania', sales_channel='Online', ship_date='5/31/2016', total_cost=881752.0, total_profit=530201.6875, total_revenue=1411953.625, unit_cost=159.4199981689453, unit_price=255.27999877929688, units_sold=5531)
# Row(order_id=UUID('b29c3d4a-6bde-4337-90dd-bb57b9d94715'), country='Montenegro', item_type='Clothes', order_date='9/4/2016', order_priority='M', region='Europe', sales_channel='Offline', ship_date='9/8/2016', total_cost=75873.28125, total_profit=155472.484375, total_revenue=231345.765625, unit_cost=35.84000015258789, unit_price=109.27999877929688, units_sold=2117)
# Row(order_id=UUID('09ec5457-1e92-44c0-ab91-15391db84ad5'), country='Nicaragua', item_type='Household', order_date='10/28/2015', order_priority='C', region='Central America and the Caribbean', sales_channel='Online', ship_date='12/7/2015', total_cost=3915289.25, total_profit=1291202.375, total_revenue=5206491.5, unit_cost=502.5400085449219, unit_price=668.27001953125, units_sold=7791)
# Row(order_id=UUID('9f262305-184c-4bfa-928a-0a14b17090b8'), country='Serbia', item_type='Clothes', order_date='7/6/2016', order_priority='L', region='Europe', sales_channel='Offline', ship_date='7/13/2016', total_cost=263352.3125, total_profit=539637.125, total_revenue=802989.4375, unit_cost=35.84000015258789, unit_price=109.27999877929688, units_sold=7348)
# Row(order_id=UUID('b65de87b-39b9-414c-a498-30ca3dc8b45c'), country='Kuwait', item_type='Household', order_date='6/13/2011', order_priority='C', region='Middle East and North Africa', sales_channel='Offline', ship_date='7/21/2011', total_cost=736723.625, total_profit=242960.1875, total_revenue=979683.8125, unit_cost=502.5400085449219, unit_price=668.27001953125, units_sold=1466)
# Row(order_id=UUID('c02a6bc4-f06a-484a-91e6-1bd4e1e09638'), country='Taiwan', item_type='Cereal', order_date='4/11/2010', order_priority='H', region='Asia', sales_channel='Online', ship_date='5/26/2010', total_cost=1100482.625, total_profit=832480.25, total_revenue=1932962.875, unit_cost=117.11000061035156, unit_price=205.6999969482422, units_sold=9397)
# Row(order_id=UUID('df8d9232-4691-47fe-977e-8992fc32da9c'), country='Morocco', item_type='Clothes', order_date='9/14/2013', order_priority='M', region='Middle East and North Africa', sales_channel='Online', ship_date='10/19/2013', total_cost=165258.234375, total_profit=338631.84375, total_revenue=503890.09375, unit_cost=35.84000015258789, unit_price=109.27999877929688, units_sold=4611)
# Row(order_id=UUID('561e02d3-9175-481e-a637-55a1299734cb'), country='United States of America', item_type='Personal Care', order_date='1/21/2016', order_priority='H', region='North America', sales_channel='Online', ship_date='2/19/2016', total_cost=241640.875, total_profit=106855.84375, total_revenue=348496.71875, unit_cost=56.66999816894531, unit_price=81.7300033569336, units_sold=4264)
# Row(order_id=UUID('25c4f710-d829-4892-b701-bcba8798fcd5'), country='Israel', item_type='Beverages', order_date='9/8/2013', order_priority='H', region='Middle East and North Africa', sales_channel='Offline', ship_date='10/13/2013', total_cost=149699.109375, total_profit=73742.9375, total_revenue=223442.046875, unit_cost=31.790000915527344, unit_price=47.45000076293945, units_sold=4709)
# Row(order_id=UUID('578367ce-14a9-4ab5-8c63-2fb9c74c605b'), country='Dominica', item_type='Household', order_date='11/19/2011', order_priority='C', region='Central America and the Caribbean', sales_channel='Offline', ship_date='12/13/2011', total_cost=3539891.75, total_profit=1167402.125, total_revenue=4707294.0, unit_cost=502.5400085449219, unit_price=668.27001953125, units_sold=7044)
# Row(order_id=UUID('dbe2cb76-9050-49f8-967c-d6dcc2f68dc9'), country='Romania', item_type='Beverages', order_date='2/19/2012', order_priority='M', region='Europe', sales_channel='Online', ship_date='3/13/2012', total_cost=145629.984375, total_profit=71738.4609375, total_revenue=217368.453125, unit_cost=31.790000915527344, unit_price=47.45000076293945, units_sold=4581)
# Row(order_id=UUID('0db940a2-f30d-4024-b68f-a38cfb30f074'), country='Estonia', item_type='Household', order_date='9/1/2011', order_priority='H', region='Europe', sales_channel='Offline', ship_date='10/21/2011', total_cost=5013339.0, total_profit=1653322.5, total_revenue=6666661.5, unit_cost=502.5400085449219, unit_price=668.27001953125, units_sold=9976)
# Row(order_id=UUID('ce653a03-976c-408f-92f4-17ae39266001'), country='Tanzania', item_type='Beverages', order_date='11/30/2016', order_priority='L', region='Sub-Saharan Africa', sales_channel='Online', ship_date='1/16/2017', total_cost=46922.0390625, total_profit=23114.16015625, total_revenue=70036.203125, unit_cost=31.790000915527344, unit_price=47.45000076293945, units_sold=1476)
# Row(order_id=UUID('14cfb24b-9a57-4cf7-8dde-65d9f1fe320e'), country='Uganda', item_type='Personal Care', order_date='6/19/2014', order_priority='M', region='Sub-Saharan Africa', sales_channel='Online', ship_date='7/21/2014', total_cost=25558.169921875, total_profit=11302.0595703125, total_revenue=36860.23046875, unit_cost=56.66999816894531, unit_price=81.7300033569336, units_sold=451)
# Row(order_id=UUID('9871be5d-81a2-4de0-9f3f-8e08e333610d'), country='Ghana', item_type='Clothes', order_date='11/2/2011', order_priority='M', region='Sub-Saharan Africa', sales_channel='Online', ship_date='12/1/2011', total_cost=137482.234375, total_profit=281715.84375, total_revenue=419198.09375, unit_cost=35.84000015258789, unit_price=109.27999877929688, units_sold=3836)
# Row(order_id=UUID('b22cd2de-8b8a-4e3d-9904-44bcb1ec4c20'), country='The Gambia', item_type='Fruits', order_date='11/20/2011', order_priority='C', region='Sub-Saharan Africa', sales_channel='Online', ship_date='11/22/2011', total_cost=60197.078125, total_profit=20964.58984375, total_revenue=81161.671875, unit_cost=6.920000076293945, unit_price=9.329999923706055, units_sold=8699)
# Row(order_id=UUID('8f7778c7-40f3-4fa9-81bd-2b15afa5bf5f'), country='Democratic Republic of the Congo', item_type='Cosmetics', order_date='10/7/2012', order_priority='M', region='Sub-Saharan Africa', sales_channel='Online', ship_date='10/25/2012', total_cost=781300.125, total_profit=515872.28125, total_revenue=1297172.375, unit_cost=263.3299865722656, unit_price=437.20001220703125, units_sold=2967)
# Row(order_id=UUID('74c7286e-62f8-4334-98bf-a8c4d8b53706'), country='Tanzania', item_type='Fruits', order_date='10/20/2014', order_priority='H', region='Sub-Saharan Africa', sales_channel='Offline', ship_date='11/29/2014', total_cost=66425.078125, total_profit=23133.58984375, total_revenue=89558.671875, unit_cost=6.920000076293945, unit_price=9.329999923706055, units_sold=9599)
# Row(order_id=UUID('0e2569b6-2ad1-4a95-b24b-29f78c3c5f63'), country='Dominican Republic', item_type='Baby Food', order_date='8/25/2011', order_priority='H', region='Central America and the Caribbean', sales_channel='Offline', ship_date='9/24/2011', total_cost=43681.078125, total_profit=26265.640625, total_revenue=69946.71875, unit_cost=159.4199981689453, unit_price=255.27999877929688, units_sold=274)
# Row(order_id=UUID('173a7513-139e-4c27-bfad-8e9ed553560e'), country='Taiwan', item_type='Fruits', order_date='2/9/2014', order_priority='M', region='Asia', sales_channel='Offline', ship_date='2/23/2014', total_cost=55595.28125, total_profit=19361.939453125, total_revenue=74957.21875, unit_cost=6.920000076293945, unit_price=9.329999923706055, units_sold=8034)
# Row(order_id=UUID('178a06aa-933c-4159-9e86-3532b1bf0fca'), country='Indonesia', item_type='Household', order_date='9/28/2011', order_priority='C', region='Asia', sales_channel='Online', ship_date='9/28/2011', total_cost=313082.40625, total_profit=103249.7890625, total_revenue=416332.21875, unit_cost=502.5400085449219, unit_price=668.27001953125, units_sold=623)
# Row(order_id=UUID('bbc770a9-888a-47f1-9e00-0a5e5534569a'), country='Singapore', item_type='Snacks', order_date='1/28/2013', order_priority='C', region='Asia', sales_channel='Online', ship_date='2/7/2013', total_cost=747949.4375, total_profit=423254.625, total_revenue=1171204.125, unit_cost=97.44000244140625, unit_price=152.5800018310547, units_sold=7676)
# Row(order_id=UUID('9f89fbae-0ba8-43a8-9dc7-b625b964c8c2'), country='United Kingdom', item_type='Cosmetics', order_date='5/1/2015', order_priority='L', region='Europe', sales_channel='Online', ship_date='5/16/2015', total_cost=273336.53125, total_profit=180477.0625, total_revenue=453813.59375, unit_cost=263.3299865722656, unit_price=437.20001220703125, units_sold=1038)
# Row(order_id=UUID('2838f198-e5c8-44c4-baa1-9b29ffaa407c'), country='The Bahamas', item_type='Fruits', order_date='6/18/2010', order_priority='L', region='Central America and the Caribbean', sales_channel='Offline', ship_date='6/30/2010', total_cost=32800.80078125, total_profit=11423.400390625, total_revenue=44224.19921875, unit_cost=6.920000076293945, unit_price=9.329999923706055, units_sold=4740)
# Row(order_id=UUID('44eef07f-84de-4985-a7bb-651daf06837f'), country='Madagascar', item_type='Clothes', order_date='10/17/2016', order_priority='L', region='Sub-Saharan Africa', sales_channel='Online', ship_date='10/26/2016', total_cost=111462.3984375, total_profit=228398.40625, total_revenue=339860.8125, unit_cost=35.84000015258789, unit_price=109.27999877929688, units_sold=3110)
# Row(order_id=UUID('b90ad20a-33a5-4064-a8a7-081177c45aa1'), country='Switzerland', item_type='Office Supplies', order_date='7/29/2014', order_priority='C', region='Europe', sales_channel='Offline', ship_date='8/27/2014', total_cost=2960249.5, total_profit=711923.75, total_revenue=3672173.25, unit_cost=524.9600219726562, unit_price=651.2100219726562, units_sold=5639)
# Row(order_id=UUID('0bd34821-17b5-4af9-b4a2-c0f48f390a75'), country='Algeria', item_type='Cosmetics', order_date='2/18/2011', order_priority='M', region='Middle East and North Africa', sales_channel='Online', ship_date='2/24/2011', total_cost=2546137.75, total_profit=1681149.0, total_revenue=4227287.0, unit_cost=263.3299865722656, unit_price=437.20001220703125, units_sold=9669)
# Row(order_id=UUID('61c133bf-7f8a-4bd9-b741-5f883e895a97'), country='Rwanda', item_type='Fruits', order_date='9/5/2012', order_priority='L', region='Sub-Saharan Africa', sales_channel='Online', ship_date='9/15/2012', total_cost=41928.28125, total_profit=14602.1904296875, total_revenue=56530.46875, unit_cost=6.920000076293945, unit_price=9.329999923706055, units_sold=6059)
# Row(order_id=UUID('914372f9-5bdf-4d45-9122-512c0333b23a'), country='Vanuatu', item_type='Fruits', order_date='11/3/2013', order_priority='C', region='Australia and Oceania', sales_channel='Online', ship_date='11/11/2013', total_cost=39686.19921875, total_profit=13821.349609375, total_revenue=53507.55078125, unit_cost=6.920000076293945, unit_price=9.329999923706055, units_sold=5735)
# Row(order_id=UUID('27662a38-a1b2-410b-a522-5f97903beab9'), country='Liberia', item_type='Baby Food', order_date='6/6/2015', order_priority='H', region='Sub-Saharan Africa', sales_channel='Offline', ship_date='6/12/2015', total_cost=211072.078125, total_profit=126918.640625, total_revenue=337990.71875, unit_cost=159.4199981689453, unit_price=255.27999877929688, units_sold=1324)
# Row(order_id=UUID('d799d3a5-39b6-49e3-b09b-45a23f31568f'), country='Romania', item_type='Cereal', order_date='4/16/2015', order_priority='M', region='Europe', sales_channel='Online', ship_date='4/18/2015', total_cost=859236.0625, total_profit=649984.8125, total_revenue=1509220.875, unit_cost=117.11000061035156, unit_price=205.6999969482422, units_sold=7337)
# Row(order_id=UUID('43360ab0-c87d-4c3e-8692-285e413936e1'), country='Tanzania', item_type='Cosmetics', order_date='5/23/2016', order_priority='L', region='Sub-Saharan Africa', sales_channel='Offline', ship_date='5/24/2016', total_cost=2045547.5, total_profit=1350622.125, total_revenue=3396169.5, unit_cost=263.3299865722656, unit_price=437.20001220703125, units_sold=7768)
# Row(order_id=UUID('d4b9356b-8e7a-4198-a741-ad3ee34b9c47'), country='Canada', item_type='Cosmetics', order_date='5/9/2011', order_priority='H', region='North America', sales_channel='Online', ship_date='6/2/2011', total_cost=1965495.125, total_profit=1297765.625, total_revenue=3263260.75, unit_cost=263.3299865722656, unit_price=437.20001220703125, units_sold=7464)
# Row(order_id=UUID('09365540-852a-4d20-b63a-ad258d37f2e1'), country='Nicaragua', item_type='Baby Food', order_date='11/11/2016', order_priority='L', region='Central America and the Caribbean', sales_channel='Online', ship_date='11/16/2016', total_cost=460883.21875, total_profit=277131.25, total_revenue=738014.5, unit_cost=159.4199981689453, unit_price=255.27999877929688, units_sold=2891)
# Row(order_id=UUID('e941b982-5e01-4cbf-afc1-39bdba12d7d7'), country='Samoa ', item_type='Household', order_date='12/5/2016', order_priority='L', region='Australia and Oceania', sales_channel='Online', ship_date='12/8/2016', total_cost=2842868.75, total_profit=937534.625, total_revenue=3780403.5, unit_cost=502.5400085449219, unit_price=668.27001953125, units_sold=5657)
# Row(order_id=UUID('39fb4154-788c-4511-b38e-3701de602f55'), country='Burundi', item_type='Beverages', order_date='3/9/2011', order_priority='H', region='Sub-Saharan Africa', sales_channel='Online', ship_date='4/9/2011', total_cost=112314.0703125, total_profit=55326.78125, total_revenue=167640.84375, unit_cost=31.790000915527344, unit_price=47.45000076293945, units_sold=3533)
# Row(order_id=UUID('7eed10e7-6522-474b-ad94-87308671da3e'), country='South Africa', item_type='Fruits', order_date='7/27/2012', order_priority='M', region='Sub-Saharan Africa', sales_channel='Offline', ship_date='7/28/2012', total_cost=11023.5595703125, total_profit=3839.1298828125, total_revenue=14862.6904296875, unit_cost=6.920000076293945, unit_price=9.329999923706055, units_sold=1593)
# Row(order_id=UUID('12dc710a-84fe-4457-9167-2864f9bc4345'), country='New Zealand', item_type='Beverages', order_date='10/11/2012', order_priority='M', region='Australia and Oceania', sales_channel='Online', ship_date='11/4/2012', total_cost=184000.515625, total_profit=90640.078125, total_revenue=274640.59375, unit_cost=31.790000915527344, unit_price=47.45000076293945, units_sold=5788)
# Row(order_id=UUID('4fe810d5-4769-48da-a417-67a1966b2de4'), country='Malawi', item_type='Meat', order_date='3/1/2016', order_priority='H', region='Sub-Saharan Africa', sales_channel='Offline', ship_date='3/12/2016', total_cost=1857730.875, total_profit=291376.8125, total_revenue=2149107.75, unit_cost=364.69000244140625, unit_price=421.8900146484375, units_sold=5094)
# Row(order_id=UUID('e1f69663-494c-4172-8970-7e2aff5835ed'), country='Ghana', item_type='Fruits', order_date='5/29/2016', order_priority='M', region='Sub-Saharan Africa', sales_channel='Offline', ship_date='6/4/2016', total_cost=9155.16015625, total_profit=3188.429931640625, total_revenue=12343.58984375, unit_cost=6.920000076293945, unit_price=9.329999923706055, units_sold=1323)
# Row(order_id=UUID('74949143-3118-4029-b12d-809e00d4ec21'), country='Solomon Islands', item_type='Household', order_date='12/17/2010', order_priority='M', region='Australia and Oceania', sales_channel='Online', ship_date='12/28/2010', total_cost=2123231.5, total_profit=700209.25, total_revenue=2823440.75, unit_cost=502.5400085449219, unit_price=668.27001953125, units_sold=4225)
# Row(order_id=UUID('6b126d17-bef2-452a-aa6a-626a5fc39f26'), country='Lebanon', item_type='Meat', order_date='3/8/2017', order_priority='L', region='Middle East and North Africa', sales_channel='Online', ship_date='4/18/2017', total_cost=3198331.25, total_profit=501644.0, total_revenue=3699975.25, unit_cost=364.69000244140625, unit_price=421.8900146484375, units_sold=8770)
# Row(order_id=UUID('67411110-ab3b-4538-8ca4-dc51586ef0e4'), country='Thailand', item_type='Fruits', order_date='9/30/2012', order_priority='C', region='Asia', sales_channel='Offline', ship_date='11/14/2012', total_cost=10760.599609375, total_profit=3747.550048828125, total_revenue=14508.150390625, unit_cost=6.920000076293945, unit_price=9.329999923706055, units_sold=1555)
# Row(order_id=UUID('ea94e4a1-9923-4927-8385-438c8f4afd50'), country='Czech Republic', item_type='Cosmetics', order_date='3/22/2014', order_priority='H', region='Europe', sales_channel='Online', ship_date='4/26/2014', total_cost=2411312.75, total_profit=1592127.625, total_revenue=4003440.5, unit_cost=263.3299865722656, unit_price=437.20001220703125, units_sold=9157)
# Row(order_id=UUID('fe53352f-f042-475c-809d-3951e81dade7'), country='Belgium', item_type='Personal Care', order_date='11/1/2011', order_priority='H', region='Europe', sales_channel='Online', ship_date='11/20/2011', total_cost=160206.09375, total_profit=70844.6171875, total_revenue=231050.703125, unit_cost=56.66999816894531, unit_price=81.7300033569336, units_sold=2827)
# Row(order_id=UUID('07e68056-852c-4916-b18f-2ec072df23b9'), country='Netherlands', item_type='Fruits', order_date='11/19/2016', order_priority='L', region='Europe', sales_channel='Online', ship_date='11/30/2016', total_cost=68418.0390625, total_profit=23827.669921875, total_revenue=92245.7109375, unit_cost=6.920000076293945, unit_price=9.329999923706055, units_sold=9887)
# Row(order_id=UUID('aa75b006-3d63-4903-8966-6e33509cf295'), country='The Bahamas', item_type='Personal Care', order_date='1/19/2011', order_priority='C', region='Central America and the Caribbean', sales_channel='Online', ship_date='2/21/2011', total_cost=517793.78125, total_profit=228973.21875, total_revenue=746767.0, unit_cost=56.66999816894531, unit_price=81.7300033569336, units_sold=9137)
# Row(order_id=UUID('451584cb-0e2b-4e11-9966-dfcec87145f2'), country='Japan', item_type='Household', order_date='7/16/2014', order_priority='M', region='Asia', sales_channel='Offline', ship_date='7/24/2014', total_cost=4217818.0, total_profit=1390971.875, total_revenue=5608790.0, unit_cost=502.5400085449219, unit_price=668.27001953125, units_sold=8393)
# Row(order_id=UUID('b859a22c-bad7-438f-b19c-00cd34b40c4a'), country='Slovakia', item_type='Beverages', order_date='10/26/2016', order_priority='L', region='Europe', sales_channel='Offline', ship_date='12/4/2016', total_cost=126301.671875, total_profit=62217.1796875, total_revenue=188518.84375, unit_cost=31.790000915527344, unit_price=47.45000076293945, units_sold=3973)
# Row(order_id=UUID('f7ccd086-f0fe-4b5b-a736-45559ef042ee'), country='Oman', item_type='Cosmetics', order_date='11/29/2010', order_priority='H', region='Middle East and North Africa', sales_channel='Online', ship_date='12/28/2010', total_cost=2090050.25, total_profit=1380006.25, total_revenue=3470056.5, unit_cost=263.3299865722656, unit_price=437.20001220703125, units_sold=7937)
# Row(order_id=UUID('f0570e3a-2685-4625-b901-7bea14b026b0'), country='South Korea', item_type='Meat', order_date='3/16/2016', order_priority='L', region='Asia', sales_channel='Offline', ship_date='4/20/2016', total_cost=2604251.25, total_profit=408465.1875, total_revenue=3012716.5, unit_cost=364.69000244140625, unit_price=421.8900146484375, units_sold=7141)
# Row(order_id=UUID('32aec347-0c06-436e-928b-fc432f70a7ff'), country='Belize', item_type='Personal Care', order_date='6/14/2015', order_priority='H', region='Central America and the Caribbean', sales_channel='Online', ship_date='8/2/2015', total_cost=200215.109375, total_profit=88536.9765625, total_revenue=288752.09375, unit_cost=56.66999816894531, unit_price=81.7300033569336, units_sold=3533)
# Row(order_id=UUID('4f8c8c4e-02b5-4780-ace6-6654b7239a52'), country='United Arab Emirates', item_type='Office Supplies', order_date='6/23/2012', order_priority='M', region='Middle East and North Africa', sales_channel='Online', ship_date='7/6/2012', total_cost=5041191.0, total_profit=1212378.75, total_revenue=6253569.5, unit_cost=524.9600219726562, unit_price=651.2100219726562, units_sold=9603)
# Row(order_id=UUID('3ffcea56-804c-4140-b476-86e133fe46a5'), country='Antigua and Barbuda ', item_type='Office Supplies', order_date='10/2/2011', order_priority='C', region='Central America and the Caribbean', sales_channel='Offline', ship_date='10/4/2011', total_cost=3305673.0, total_profit=794996.25, total_revenue=4100669.25, unit_cost=524.9600219726562, unit_price=651.2100219726562, units_sold=6297)
# Row(order_id=UUID('bbc3c871-01a7-468f-99c3-052f8a31542d'), country='Sweden', item_type='Beverages', order_date='9/13/2012', order_priority='H', region='Europe', sales_channel='Online', ship_date='10/12/2012', total_cost=78998.1484375, total_profit=38915.1015625, total_revenue=117913.25, unit_cost=31.790000915527344, unit_price=47.45000076293945, units_sold=2485)
# Row(order_id=UUID('7d31fe35-a78a-4967-bef7-3a955c5fd0d7'), country='Nepal', item_type='Meat', order_date='2/21/2014', order_priority='H', region='Asia', sales_channel='Online', ship_date='3/14/2014', total_cost=3463096.25, total_profit=543171.1875, total_revenue=4006267.5, unit_cost=364.69000244140625, unit_price=421.8900146484375, units_sold=9496)
# Row(order_id=UUID('c4294cb9-0638-4768-88a8-34a960cd050a'), country='Sao Tome and Principe', item_type='Clothes', order_date='11/11/2015', order_priority='L', region='Sub-Saharan Africa', sales_channel='Offline', ship_date='12/28/2015', total_cost=98918.3984375, total_profit=202694.40625, total_revenue=301612.8125, unit_cost=35.84000015258789, unit_price=109.27999877929688, units_sold=2760)
# Row(order_id=UUID('31fb59f3-4a41-4b55-a467-1d71af6e1df5'), country='Pakistan', item_type='Meat', order_date='12/28/2013', order_priority='M', region='Middle East and North Africa', sales_channel='Online', ship_date='2/15/2014', total_cost=3635594.5, total_profit=570226.8125, total_revenue=4205821.5, unit_cost=364.69000244140625, unit_price=421.8900146484375, units_sold=9969)
# Row(order_id=UUID('d3035a7b-28e2-4013-9ed4-d0b5d2b44628'), country='Sri Lanka', item_type='Fruits', order_date='11/7/2011', order_priority='L', region='Asia', sales_channel='Online', ship_date='12/18/2011', total_cost=9542.6796875, total_profit=3323.389892578125, total_revenue=12866.0703125, unit_cost=6.920000076293945, unit_price=9.329999923706055, units_sold=1379)
# Row(order_id=UUID('cbc2d3bc-73e8-4178-a06d-d23ef25efbd2'), country='Djibouti', item_type='Clothes', order_date='5/17/2017', order_priority='H', region='Sub-Saharan Africa', sales_channel='Offline', ship_date='7/2/2017', total_cost=20142.080078125, total_profit=41273.28125, total_revenue=61415.359375, unit_cost=35.84000015258789, unit_price=109.27999877929688, units_sold=562)
# Row(order_id=UUID('2c823e3a-2e30-4246-8e7a-7cb7d990532c'), country='Moldova ', item_type='Fruits', order_date='1/27/2013', order_priority='C', region='Europe', sales_channel='Online', ship_date='3/3/2013', total_cost=25853.119140625, total_profit=9003.759765625, total_revenue=34856.87890625, unit_cost=6.920000076293945, unit_price=9.329999923706055, units_sold=3736)
# Row(order_id=UUID('ca84e6f1-034a-4be9-8653-828e534ae2fc'), country='Ghana', item_type='Office Supplies', order_date='3/23/2017', order_priority='L', region='Sub-Saharan Africa', sales_channel='Online', ship_date='4/15/2017', total_cost=470364.15625, total_profit=113120.0, total_revenue=583484.1875, unit_cost=524.9600219726562, unit_price=651.2100219726562, units_sold=896)
# Row(order_id=UUID('15010343-d465-4f31-a808-4bdb6a0c2892'), country='Finland', item_type='Household', order_date='1/15/2016', order_priority='H', region='Europe', sales_channel='Offline', ship_date='1/31/2016', total_cost=4094696.0, total_profit=1350368.0, total_revenue=5445064.0, unit_cost=502.5400085449219, unit_price=668.27001953125, units_sold=8148)
# Row(order_id=UUID('b8d81c32-18bb-4e00-a13c-559ec3bd4e88'), country='Mauritius ', item_type='Clothes', order_date='11/17/2012', order_priority='M', region='Sub-Saharan Africa', sales_channel='Offline', ship_date='12/2/2012', total_cost=197836.796875, total_profit=405388.8125, total_revenue=603225.625, unit_cost=35.84000015258789, unit_price=109.27999877929688, units_sold=5520)
# Row(order_id=UUID('f94ee47e-334b-47b7-86f2-85de0ed279b1'), country='Ethiopia', item_type='Cosmetics', order_date='7/7/2011', order_priority='M', region='Sub-Saharan Africa', sales_channel='Online', ship_date='7/25/2011', total_cost=174324.453125, total_profit=115101.9375, total_revenue=289426.40625, unit_cost=263.3299865722656, unit_price=437.20001220703125, units_sold=662)
# Row(order_id=UUID('ea20395f-744e-4aeb-899b-4f9c142115f1'), country='Vanuatu', item_type='Cereal', order_date='6/20/2014', order_priority='C', region='Australia and Oceania', sales_channel='Offline', ship_date='8/5/2014', total_cost=665301.9375, total_profit=503279.78125, total_revenue=1168581.75, unit_cost=117.11000061035156, unit_price=205.6999969482422, units_sold=5681)
# Row(order_id=UUID('374890b5-3c81-4d50-95d0-6d061522e7c1'), country='Papua New Guinea', item_type='Clothes', order_date='6/20/2011', order_priority='L', region='Australia and Oceania', sales_channel='Offline', ship_date='7/14/2011', total_cost=325857.28125, total_profit=667716.5, total_revenue=993573.75, unit_cost=35.84000015258789, unit_price=109.27999877929688, units_sold=9092)
# Row(order_id=UUID('c016de96-3041-4b02-9ebf-57e9697515ef'), country='Seychelles ', item_type='Beverages', order_date='1/18/2013', order_priority='M', region='Sub-Saharan Africa', sales_channel='Online', ship_date='2/16/2013', total_cost=18978.630859375, total_profit=9349.01953125, total_revenue=28327.650390625, unit_cost=31.790000915527344, unit_price=47.45000076293945, units_sold=597)
# Row(order_id=UUID('1ff7610e-2873-4534-ac51-206189dcf523'), country='Monaco', item_type='Beverages', order_date='5/29/2016', order_priority='M', region='Europe', sales_channel='Offline', ship_date='6/14/2016', total_cost=82940.109375, total_profit=40856.94140625, total_revenue=123797.046875, unit_cost=31.790000915527344, unit_price=47.45000076293945, units_sold=2609)
# Row(order_id=UUID('3404847f-3593-4e68-af55-7f2d005d4280'), country='Dominica', item_type='Beverages', order_date='6/12/2012', order_priority='L', region='Central America and the Caribbean', sales_channel='Online', ship_date='7/18/2012', total_cost=200308.796875, total_profit=98673.65625, total_revenue=298982.4375, unit_cost=31.790000915527344, unit_price=47.45000076293945, units_sold=6301)
# Row(order_id=UUID('685b74f8-f968-49cb-8381-0aa1a1de5401'), country='Italy', item_type='Cereal', order_date='11/30/2015', order_priority='C', region='Europe', sales_channel='Online', ship_date='12/5/2015', total_cost=366085.875, total_profit=276932.34375, total_revenue=643018.1875, unit_cost=117.11000061035156, unit_price=205.6999969482422, units_sold=3126)
# Row(order_id=UUID('34053a2e-d484-4f76-9b98-04d8f95d2cc1'), country='Kazakhstan', item_type='Snacks', order_date='9/8/2013', order_priority='L', region='Asia', sales_channel='Online', ship_date='10/25/2013', total_cost=131738.875, total_profit=74549.28125, total_revenue=206288.15625, unit_cost=97.44000244140625, unit_price=152.5800018310547, units_sold=1352)
# Row(order_id=UUID('c9ad0afb-e624-4d76-b615-73e7c27861b6'), country='Turkmenistan', item_type='Vegetables', order_date='4/13/2015', order_priority='M', region='Asia', sales_channel='Online', ship_date='6/2/2015', total_cost=606503.125, total_profit=421077.09375, total_revenue=1027580.1875, unit_cost=90.93000030517578, unit_price=154.05999755859375, units_sold=6670)
# Row(order_id=UUID('02b6a6d3-3010-4cb8-8205-2fe10b692b4f'), country='Finland', item_type='Vegetables', order_date='10/9/2012', order_priority='C', region='Europe', sales_channel='Offline', ship_date='11/27/2012', total_cost=63469.140625, total_profit=44064.73828125, total_revenue=107533.8828125, unit_cost=90.93000030517578, unit_price=154.05999755859375, units_sold=698)
# Row(order_id=UUID('2631f0a9-be8b-419e-a32a-b42792922edd'), country='Brunei', item_type='Cereal', order_date='5/28/2013', order_priority='L', region='Asia', sales_channel='Offline', ship_date='7/16/2013', total_cost=494438.40625, total_profit=374026.96875, total_revenue=868465.375, unit_cost=117.11000061035156, unit_price=205.6999969482422, units_sold=4222)
# Row(order_id=UUID('5a2da3e4-8994-46f0-8ba1-3e95ec23fac6'), country='Zimbabwe', item_type='Office Supplies', order_date='3/28/2011', order_priority='C', region='Sub-Saharan Africa', sales_channel='Offline', ship_date='4/8/2011', total_cost=5051690.0, total_profit=1214903.75, total_revenue=6266594.0, unit_cost=524.9600219726562, unit_price=651.2100219726562, units_sold=9623)
# Row(order_id=UUID('f4d048cb-4960-4c4b-a419-bd93a776ae24'), country='Italy', item_type='Office Supplies', order_date='3/29/2011', order_priority='H', region='Europe', sales_channel='Online', ship_date='4/11/2011', total_cost=1529208.5, total_profit=367766.25, total_revenue=1896974.75, unit_cost=524.9600219726562, unit_price=651.2100219726562, units_sold=2913)
# Row(order_id=UUID('75b8c0e1-5d73-4465-88ca-fb5f60f91bbd'), country='Vietnam', item_type='Personal Care', order_date='4/4/2010', order_priority='M', region='Asia', sales_channel='Online', ship_date='5/6/2010', total_cost=452453.28125, total_profit=200079.046875, total_revenue=652532.3125, unit_cost=56.66999816894531, unit_price=81.7300033569336, units_sold=7984)
# Row(order_id=UUID('e07dd9f8-4aec-4890-9e31-7eae70645b94'), country='Mali', item_type='Household', order_date='8/19/2010', order_priority='M', region='Sub-Saharan Africa', sales_channel='Offline', ship_date='9/7/2010', total_cost=2169465.25, total_profit=715456.4375, total_revenue=2884921.5, unit_cost=502.5400085449219, unit_price=668.27001953125, units_sold=4317)
# Row(order_id=UUID('8ae3f83a-58a1-404d-a0eb-512cffe4633a'), country='Turkmenistan', item_type='Meat', order_date='4/30/2017', order_priority='M', region='Asia', sales_channel='Online', ship_date='5/14/2017', total_cost=1898576.125, total_profit=297783.1875, total_revenue=2196359.25, unit_cost=364.69000244140625, unit_price=421.8900146484375, units_sold=5206)
# Row(order_id=UUID('ddcbb35b-2bf1-435f-8d48-e61c76250253'), country='Albania', item_type='Personal Care', order_date='2/6/2016', order_priority='M', region='Europe', sales_channel='Offline', ship_date='2/11/2016', total_cost=87441.8125, total_profit=38667.578125, total_revenue=126109.390625, unit_cost=56.66999816894531, unit_price=81.7300033569336, units_sold=1543)
# Row(order_id=UUID('2fb3ff22-41b6-4d7c-83be-bfa62afa8ccc'), country='China', item_type='Office Supplies', order_date='2/10/2016', order_priority='M', region='Asia', sales_channel='Online', ship_date='3/29/2016', total_cost=3040043.25, total_profit=731113.75, total_revenue=3771157.0, unit_cost=524.9600219726562, unit_price=651.2100219726562, units_sold=5791)
# Row(order_id=UUID('0a242212-d649-4caf-a2bf-0208c335925e'), country='Greece', item_type='Cereal', order_date='8/22/2015', order_priority='H', region='Europe', sales_channel='Online', ship_date='10/8/2015', total_cost=1015812.125, total_profit=768429.6875, total_revenue=1784241.75, unit_cost=117.11000061035156, unit_price=205.6999969482422, units_sold=8674)
# Row(order_id=UUID('7ebac0ab-f63d-40ff-891e-284cd61d74b0'), country='East Timor', item_type='Cereal', order_date='12/7/2015', order_priority='M', region='Australia and Oceania', sales_channel='Offline', ship_date='12/30/2015', total_cost=30331.490234375, total_profit=22944.810546875, total_revenue=53276.30078125, unit_cost=117.11000061035156, unit_price=205.6999969482422, units_sold=259)
# Row(order_id=UUID('dd5e047a-c80b-4568-ab93-7bd36d2ae664'), country='Tunisia ', item_type='Cosmetics', order_date='7/1/2012', order_priority='H', region='Middle East and North Africa', sales_channel='Offline', ship_date='7/20/2012', total_cost=645158.5, total_profit=425981.5, total_revenue=1071140.0, unit_cost=263.3299865722656, unit_price=437.20001220703125, units_sold=2450)
# Row(order_id=UUID('4e1fe96e-0b5f-4f3f-8730-632ce05f621a'), country='Indonesia', item_type='Personal Care', order_date='10/22/2012', order_priority='L', region='Asia', sales_channel='Offline', ship_date='10/31/2012', total_cost=527371.0, total_profit=233208.359375, total_revenue=760579.375, unit_cost=56.66999816894531, unit_price=81.7300033569336, units_sold=9306)
# Row(order_id=UUID('f2d6221d-aed3-404a-9278-9921edaca75a'), country='Uganda', item_type='Cosmetics', order_date='2/28/2015', order_priority='M', region='Sub-Saharan Africa', sales_channel='Online', ship_date='3/15/2015', total_cost=1588143.25, total_profit=1048610.0, total_revenue=2636753.25, unit_cost=263.3299865722656, unit_price=437.20001220703125, units_sold=6031)
# Row(order_id=UUID('45ed3a55-cf73-40dd-a144-e39a45051ef5'), country='Iceland', item_type='Baby Food', order_date='10/2/2010', order_priority='M', region='Europe', sales_channel='Offline', ship_date='11/3/2010', total_cost=392492.03125, total_profit=236007.3125, total_revenue=628499.375, unit_cost=159.4199981689453, unit_price=255.27999877929688, units_sold=2462)
# Row(order_id=UUID('a2c5a346-fa83-422a-9293-2bbfccbcc2b5'), country='France', item_type='Cosmetics', order_date='12/7/2015', order_priority='M', region='Europe', sales_channel='Online', ship_date='1/18/2016', total_cost=1516254.125, total_profit=1001143.4375, total_revenue=2517397.5, unit_cost=263.3299865722656, unit_price=437.20001220703125, units_sold=5758)
# Row(order_id=UUID('775a8671-d103-436f-945d-c2e93bc66e9c'), country='Togo', item_type='Cosmetics', order_date='9/8/2015', order_priority='M', region='Sub-Saharan Africa', sales_channel='Online', ship_date='9/9/2015', total_cost=1265564.0, total_profit=835619.25, total_revenue=2101183.25, unit_cost=263.3299865722656, unit_price=437.20001220703125, units_sold=4806)
# Row(order_id=UUID('ea70f6cc-adc7-49cf-a9cd-c0ce41a8bddf'), country='Egypt', item_type='Clothes', order_date='8/9/2016', order_priority='C', region='Middle East and North Africa', sales_channel='Online', ship_date='8/24/2016', total_cost=42721.28125, total_profit=87540.4765625, total_revenue=130261.7578125, unit_cost=35.84000015258789, unit_price=109.27999877929688, units_sold=1192)
# Row(order_id=UUID('6ba9967b-c175-4553-9a38-77bee7bb82f7'), country='Italy', item_type='Cereal', order_date='11/15/2011', order_priority='M', region='Europe', sales_channel='Online', ship_date='12/28/2011', total_cost=829138.8125, total_profit=627217.1875, total_revenue=1456356.0, unit_cost=117.11000061035156, unit_price=205.6999969482422, units_sold=7080)
# Row(order_id=UUID('347aeee8-2675-4f13-83b9-66cbf2d240f0'), country='Papua New Guinea', item_type='Meat', order_date='5/15/2015', order_priority='M', region='Australia and Oceania', sales_channel='Offline', ship_date='6/4/2015', total_cost=131288.40625, total_profit=20592.0, total_revenue=151880.40625, unit_cost=364.69000244140625, unit_price=421.8900146484375, units_sold=360)
#
# ------ Silver Table Data ------
# Row(order_id=UUID('2d873d8e-6d62-410e-8fac-27da678744b3'), country='Albania', item_type='Baby Food', region='Europe', total_profit=756335.375)
# Row(order_id=UUID('4611c8d7-e613-485f-9c5d-c65a1918d4ee'), country='Saint Lucia', item_type='Fruits', region='Central America and the Caribbean', total_profit=8630.2099609375)
# Row(order_id=UUID('4704ef3a-8038-4606-979c-8fa11de77f94'), country='Haiti', item_type='Office Supplies', region='Central America and the Caribbean', total_profit=259065.0)
# Row(order_id=UUID('f6e1b36e-6b2d-4680-b00b-c8ca27f9d547'), country='India', item_type='Snacks', region='Asia', total_profit=294943.875)
# Row(order_id=UUID('f4f82d56-ccea-4ccc-874f-ba8f0757d1d3'), country='Thailand', item_type='Meat', region='Asia', total_profit=251737.203125)
# Row(order_id=UUID('29906647-8592-471e-baf5-3b0a551d29ae'), country='Malaysia', item_type='Beverages', region='Asia', total_profit=143351.640625)
# Row(order_id=UUID('ce22dac7-3fdb-4a8b-b8b9-c0b497281570'), country='Tonga', item_type='Baby Food', region='Australia and Oceania', total_profit=530201.6875)
# Row(order_id=UUID('b29c3d4a-6bde-4337-90dd-bb57b9d94715'), country='Montenegro', item_type='Clothes', region='Europe', total_profit=155472.484375)
# Row(order_id=UUID('09ec5457-1e92-44c0-ab91-15391db84ad5'), country='Nicaragua', item_type='Household', region='Central America and the Caribbean', total_profit=1291202.375)
# Row(order_id=UUID('9f262305-184c-4bfa-928a-0a14b17090b8'), country='Serbia', item_type='Clothes', region='Europe', total_profit=539637.125)
# Row(order_id=UUID('b65de87b-39b9-414c-a498-30ca3dc8b45c'), country='Kuwait', item_type='Household', region='Middle East and North Africa', total_profit=242960.1875)
# Row(order_id=UUID('c02a6bc4-f06a-484a-91e6-1bd4e1e09638'), country='Taiwan', item_type='Cereal', region='Asia', total_profit=832480.25)
# Row(order_id=UUID('df8d9232-4691-47fe-977e-8992fc32da9c'), country='Morocco', item_type='Clothes', region='Middle East and North Africa', total_profit=338631.84375)
# Row(order_id=UUID('561e02d3-9175-481e-a637-55a1299734cb'), country='United States of America', item_type='Personal Care', region='North America', total_profit=106855.84375)
# Row(order_id=UUID('25c4f710-d829-4892-b701-bcba8798fcd5'), country='Israel', item_type='Beverages', region='Middle East and North Africa', total_profit=73742.9375)
# Row(order_id=UUID('578367ce-14a9-4ab5-8c63-2fb9c74c605b'), country='Dominica', item_type='Household', region='Central America and the Caribbean', total_profit=1167402.125)
# Row(order_id=UUID('dbe2cb76-9050-49f8-967c-d6dcc2f68dc9'), country='Romania', item_type='Beverages', region='Europe', total_profit=71738.4609375)
# Row(order_id=UUID('0db940a2-f30d-4024-b68f-a38cfb30f074'), country='Estonia', item_type='Household', region='Europe', total_profit=1653322.5)
# Row(order_id=UUID('ce653a03-976c-408f-92f4-17ae39266001'), country='Tanzania', item_type='Beverages', region='Sub-Saharan Africa', total_profit=23114.16015625)
# Row(order_id=UUID('14cfb24b-9a57-4cf7-8dde-65d9f1fe320e'), country='Uganda', item_type='Personal Care', region='Sub-Saharan Africa', total_profit=11302.0595703125)
# Row(order_id=UUID('9871be5d-81a2-4de0-9f3f-8e08e333610d'), country='Ghana', item_type='Clothes', region='Sub-Saharan Africa', total_profit=281715.84375)
# Row(order_id=UUID('b22cd2de-8b8a-4e3d-9904-44bcb1ec4c20'), country='The Gambia', item_type='Fruits', region='Sub-Saharan Africa', total_profit=20964.58984375)
# Row(order_id=UUID('8f7778c7-40f3-4fa9-81bd-2b15afa5bf5f'), country='Democratic Republic of the Congo', item_type='Cosmetics', region='Sub-Saharan Africa', total_profit=515872.28125)
# Row(order_id=UUID('74c7286e-62f8-4334-98bf-a8c4d8b53706'), country='Tanzania', item_type='Fruits', region='Sub-Saharan Africa', total_profit=23133.58984375)
# Row(order_id=UUID('0e2569b6-2ad1-4a95-b24b-29f78c3c5f63'), country='Dominican Republic', item_type='Baby Food', region='Central America and the Caribbean', total_profit=26265.640625)
# Row(order_id=UUID('173a7513-139e-4c27-bfad-8e9ed553560e'), country='Taiwan', item_type='Fruits', region='Asia', total_profit=19361.939453125)
# Row(order_id=UUID('178a06aa-933c-4159-9e86-3532b1bf0fca'), country='Indonesia', item_type='Household', region='Asia', total_profit=103249.7890625)
# Row(order_id=UUID('bbc770a9-888a-47f1-9e00-0a5e5534569a'), country='Singapore', item_type='Snacks', region='Asia', total_profit=423254.625)
# Row(order_id=UUID('9f89fbae-0ba8-43a8-9dc7-b625b964c8c2'), country='United Kingdom', item_type='Cosmetics', region='Europe', total_profit=180477.0625)
# Row(order_id=UUID('2838f198-e5c8-44c4-baa1-9b29ffaa407c'), country='The Bahamas', item_type='Fruits', region='Central America and the Caribbean', total_profit=11423.400390625)
# Row(order_id=UUID('44eef07f-84de-4985-a7bb-651daf06837f'), country='Madagascar', item_type='Clothes', region='Sub-Saharan Africa', total_profit=228398.40625)
# Row(order_id=UUID('b90ad20a-33a5-4064-a8a7-081177c45aa1'), country='Switzerland', item_type='Office Supplies', region='Europe', total_profit=711923.75)
# Row(order_id=UUID('0bd34821-17b5-4af9-b4a2-c0f48f390a75'), country='Algeria', item_type='Cosmetics', region='Middle East and North Africa', total_profit=1681149.0)
# Row(order_id=UUID('61c133bf-7f8a-4bd9-b741-5f883e895a97'), country='Rwanda', item_type='Fruits', region='Sub-Saharan Africa', total_profit=14602.1904296875)
# Row(order_id=UUID('914372f9-5bdf-4d45-9122-512c0333b23a'), country='Vanuatu', item_type='Fruits', region='Australia and Oceania', total_profit=13821.349609375)
# Row(order_id=UUID('27662a38-a1b2-410b-a522-5f97903beab9'), country='Liberia', item_type='Baby Food', region='Sub-Saharan Africa', total_profit=126918.640625)
# Row(order_id=UUID('d799d3a5-39b6-49e3-b09b-45a23f31568f'), country='Romania', item_type='Cereal', region='Europe', total_profit=649984.8125)
# Row(order_id=UUID('43360ab0-c87d-4c3e-8692-285e413936e1'), country='Tanzania', item_type='Cosmetics', region='Sub-Saharan Africa', total_profit=1350622.125)
# Row(order_id=UUID('d4b9356b-8e7a-4198-a741-ad3ee34b9c47'), country='Canada', item_type='Cosmetics', region='North America', total_profit=1297765.625)
# Row(order_id=UUID('09365540-852a-4d20-b63a-ad258d37f2e1'), country='Nicaragua', item_type='Baby Food', region='Central America and the Caribbean', total_profit=277131.25)
# Row(order_id=UUID('e941b982-5e01-4cbf-afc1-39bdba12d7d7'), country='Samoa ', item_type='Household', region='Australia and Oceania', total_profit=937534.625)
# Row(order_id=UUID('39fb4154-788c-4511-b38e-3701de602f55'), country='Burundi', item_type='Beverages', region='Sub-Saharan Africa', total_profit=55326.78125)
# Row(order_id=UUID('7eed10e7-6522-474b-ad94-87308671da3e'), country='South Africa', item_type='Fruits', region='Sub-Saharan Africa', total_profit=3839.1298828125)
# Row(order_id=UUID('12dc710a-84fe-4457-9167-2864f9bc4345'), country='New Zealand', item_type='Beverages', region='Australia and Oceania', total_profit=90640.078125)
# Row(order_id=UUID('4fe810d5-4769-48da-a417-67a1966b2de4'), country='Malawi', item_type='Meat', region='Sub-Saharan Africa', total_profit=291376.8125)
# Row(order_id=UUID('e1f69663-494c-4172-8970-7e2aff5835ed'), country='Ghana', item_type='Fruits', region='Sub-Saharan Africa', total_profit=3188.429931640625)
# Row(order_id=UUID('74949143-3118-4029-b12d-809e00d4ec21'), country='Solomon Islands', item_type='Household', region='Australia and Oceania', total_profit=700209.25)
# Row(order_id=UUID('6b126d17-bef2-452a-aa6a-626a5fc39f26'), country='Lebanon', item_type='Meat', region='Middle East and North Africa', total_profit=501644.0)
# Row(order_id=UUID('67411110-ab3b-4538-8ca4-dc51586ef0e4'), country='Thailand', item_type='Fruits', region='Asia', total_profit=3747.550048828125)
# Row(order_id=UUID('ea94e4a1-9923-4927-8385-438c8f4afd50'), country='Czech Republic', item_type='Cosmetics', region='Europe', total_profit=1592127.625)
# Row(order_id=UUID('fe53352f-f042-475c-809d-3951e81dade7'), country='Belgium', item_type='Personal Care', region='Europe', total_profit=70844.6171875)
# Row(order_id=UUID('07e68056-852c-4916-b18f-2ec072df23b9'), country='Netherlands', item_type='Fruits', region='Europe', total_profit=23827.669921875)
# Row(order_id=UUID('aa75b006-3d63-4903-8966-6e33509cf295'), country='The Bahamas', item_type='Personal Care', region='Central America and the Caribbean', total_profit=228973.21875)
# Row(order_id=UUID('451584cb-0e2b-4e11-9966-dfcec87145f2'), country='Japan', item_type='Household', region='Asia', total_profit=1390971.875)
# Row(order_id=UUID('b859a22c-bad7-438f-b19c-00cd34b40c4a'), country='Slovakia', item_type='Beverages', region='Europe', total_profit=62217.1796875)
# Row(order_id=UUID('f7ccd086-f0fe-4b5b-a736-45559ef042ee'), country='Oman', item_type='Cosmetics', region='Middle East and North Africa', total_profit=1380006.25)
# Row(order_id=UUID('f0570e3a-2685-4625-b901-7bea14b026b0'), country='South Korea', item_type='Meat', region='Asia', total_profit=408465.1875)
# Row(order_id=UUID('32aec347-0c06-436e-928b-fc432f70a7ff'), country='Belize', item_type='Personal Care', region='Central America and the Caribbean', total_profit=88536.9765625)
# Row(order_id=UUID('4f8c8c4e-02b5-4780-ace6-6654b7239a52'), country='United Arab Emirates', item_type='Office Supplies', region='Middle East and North Africa', total_profit=1212378.75)
# Row(order_id=UUID('3ffcea56-804c-4140-b476-86e133fe46a5'), country='Antigua and Barbuda ', item_type='Office Supplies', region='Central America and the Caribbean', total_profit=794996.25)
# Row(order_id=UUID('bbc3c871-01a7-468f-99c3-052f8a31542d'), country='Sweden', item_type='Beverages', region='Europe', total_profit=38915.1015625)
# Row(order_id=UUID('7d31fe35-a78a-4967-bef7-3a955c5fd0d7'), country='Nepal', item_type='Meat', region='Asia', total_profit=543171.1875)
# Row(order_id=UUID('c4294cb9-0638-4768-88a8-34a960cd050a'), country='Sao Tome and Principe', item_type='Clothes', region='Sub-Saharan Africa', total_profit=202694.40625)
# Row(order_id=UUID('31fb59f3-4a41-4b55-a467-1d71af6e1df5'), country='Pakistan', item_type='Meat', region='Middle East and North Africa', total_profit=570226.8125)
# Row(order_id=UUID('d3035a7b-28e2-4013-9ed4-d0b5d2b44628'), country='Sri Lanka', item_type='Fruits', region='Asia', total_profit=3323.389892578125)
# Row(order_id=UUID('cbc2d3bc-73e8-4178-a06d-d23ef25efbd2'), country='Djibouti', item_type='Clothes', region='Sub-Saharan Africa', total_profit=41273.28125)
# Row(order_id=UUID('2c823e3a-2e30-4246-8e7a-7cb7d990532c'), country='Moldova ', item_type='Fruits', region='Europe', total_profit=9003.759765625)
# Row(order_id=UUID('ca84e6f1-034a-4be9-8653-828e534ae2fc'), country='Ghana', item_type='Office Supplies', region='Sub-Saharan Africa', total_profit=113120.0)
# Row(order_id=UUID('15010343-d465-4f31-a808-4bdb6a0c2892'), country='Finland', item_type='Household', region='Europe', total_profit=1350368.0)
# Row(order_id=UUID('b8d81c32-18bb-4e00-a13c-559ec3bd4e88'), country='Mauritius ', item_type='Clothes', region='Sub-Saharan Africa', total_profit=405388.8125)
# Row(order_id=UUID('f94ee47e-334b-47b7-86f2-85de0ed279b1'), country='Ethiopia', item_type='Cosmetics', region='Sub-Saharan Africa', total_profit=115101.9375)
# Row(order_id=UUID('ea20395f-744e-4aeb-899b-4f9c142115f1'), country='Vanuatu', item_type='Cereal', region='Australia and Oceania', total_profit=503279.78125)
# Row(order_id=UUID('374890b5-3c81-4d50-95d0-6d061522e7c1'), country='Papua New Guinea', item_type='Clothes', region='Australia and Oceania', total_profit=667716.5)
# Row(order_id=UUID('c016de96-3041-4b02-9ebf-57e9697515ef'), country='Seychelles ', item_type='Beverages', region='Sub-Saharan Africa', total_profit=9349.01953125)
# Row(order_id=UUID('1ff7610e-2873-4534-ac51-206189dcf523'), country='Monaco', item_type='Beverages', region='Europe', total_profit=40856.94140625)
# Row(order_id=UUID('3404847f-3593-4e68-af55-7f2d005d4280'), country='Dominica', item_type='Beverages', region='Central America and the Caribbean', total_profit=98673.65625)
# Row(order_id=UUID('685b74f8-f968-49cb-8381-0aa1a1de5401'), country='Italy', item_type='Cereal', region='Europe', total_profit=276932.34375)
# Row(order_id=UUID('34053a2e-d484-4f76-9b98-04d8f95d2cc1'), country='Kazakhstan', item_type='Snacks', region='Asia', total_profit=74549.28125)
# Row(order_id=UUID('c9ad0afb-e624-4d76-b615-73e7c27861b6'), country='Turkmenistan', item_type='Vegetables', region='Asia', total_profit=421077.09375)
# Row(order_id=UUID('02b6a6d3-3010-4cb8-8205-2fe10b692b4f'), country='Finland', item_type='Vegetables', region='Europe', total_profit=44064.73828125)
# Row(order_id=UUID('2631f0a9-be8b-419e-a32a-b42792922edd'), country='Brunei', item_type='Cereal', region='Asia', total_profit=374026.96875)
# Row(order_id=UUID('5a2da3e4-8994-46f0-8ba1-3e95ec23fac6'), country='Zimbabwe', item_type='Office Supplies', region='Sub-Saharan Africa', total_profit=1214903.75)
# Row(order_id=UUID('f4d048cb-4960-4c4b-a419-bd93a776ae24'), country='Italy', item_type='Office Supplies', region='Europe', total_profit=367766.25)
# Row(order_id=UUID('75b8c0e1-5d73-4465-88ca-fb5f60f91bbd'), country='Vietnam', item_type='Personal Care', region='Asia', total_profit=200079.046875)
# Row(order_id=UUID('e07dd9f8-4aec-4890-9e31-7eae70645b94'), country='Mali', item_type='Household', region='Sub-Saharan Africa', total_profit=715456.4375)
# Row(order_id=UUID('8ae3f83a-58a1-404d-a0eb-512cffe4633a'), country='Turkmenistan', item_type='Meat', region='Asia', total_profit=297783.1875)
# Row(order_id=UUID('ddcbb35b-2bf1-435f-8d48-e61c76250253'), country='Albania', item_type='Personal Care', region='Europe', total_profit=38667.578125)
# Row(order_id=UUID('2fb3ff22-41b6-4d7c-83be-bfa62afa8ccc'), country='China', item_type='Office Supplies', region='Asia', total_profit=731113.75)
# Row(order_id=UUID('0a242212-d649-4caf-a2bf-0208c335925e'), country='Greece', item_type='Cereal', region='Europe', total_profit=768429.6875)
# Row(order_id=UUID('7ebac0ab-f63d-40ff-891e-284cd61d74b0'), country='East Timor', item_type='Cereal', region='Australia and Oceania', total_profit=22944.810546875)
# Row(order_id=UUID('dd5e047a-c80b-4568-ab93-7bd36d2ae664'), country='Tunisia ', item_type='Cosmetics', region='Middle East and North Africa', total_profit=425981.5)
# Row(order_id=UUID('4e1fe96e-0b5f-4f3f-8730-632ce05f621a'), country='Indonesia', item_type='Personal Care', region='Asia', total_profit=233208.359375)
# Row(order_id=UUID('f2d6221d-aed3-404a-9278-9921edaca75a'), country='Uganda', item_type='Cosmetics', region='Sub-Saharan Africa', total_profit=1048610.0)
# Row(order_id=UUID('45ed3a55-cf73-40dd-a144-e39a45051ef5'), country='Iceland', item_type='Baby Food', region='Europe', total_profit=236007.3125)
# Row(order_id=UUID('a2c5a346-fa83-422a-9293-2bbfccbcc2b5'), country='France', item_type='Cosmetics', region='Europe', total_profit=1001143.4375)
# Row(order_id=UUID('775a8671-d103-436f-945d-c2e93bc66e9c'), country='Togo', item_type='Cosmetics', region='Sub-Saharan Africa', total_profit=835619.25)
# Row(order_id=UUID('ea70f6cc-adc7-49cf-a9cd-c0ce41a8bddf'), country='Egypt', item_type='Clothes', region='Middle East and North Africa', total_profit=87540.4765625)
# Row(order_id=UUID('6ba9967b-c175-4553-9a38-77bee7bb82f7'), country='Italy', item_type='Cereal', region='Europe', total_profit=627217.1875)
# Row(order_id=UUID('347aeee8-2675-4f13-83b9-66cbf2d240f0'), country='Papua New Guinea', item_type='Meat', region='Australia and Oceania', total_profit=20592.0)
